# %%
# %load_ext autoreload
# %autoreload 2

import matplotlib.pyplot as plt
import scanpy as sc
import seaborn as sns

import ncem

sc.set_figure_params(scanpy=True, fontsize=14)
plt.rcParams['axes.grid'] = False
sns.set_palette("colorblind")

dir_gs = "/storage/groups/ml01/workspace/anna.schaar/tissue/grid_searches_gen/"
#dir_gs = "/Users/anna.schaar/phd/grid_searches/tissue/"

# %% [markdown]
# ## MERFISH - brain

# %%
gs_linear = ncem.train.GridSearchContainer(
    dir_gs, 
    gs_ids=[
        "210520_LINEAR_BASELINE_MAX_NODES_PATIENT_1_ZHANG",
        "210520_LINEAR_MAX_NODES_PATIENT_1_ZHANG"
    ],
    lateral_resolution=1
)
gs_linear.load_gs()
# Out:
# 210520_LINEAR_BASELINE_MAX_NODES_PATIENT_1_ZHANG: loaded 1 runs with 3-fold cross validation
# 210520_LINEAR_MAX_NODES_PATIENT_1_ZHANG: loaded 9 runs with 3-fold cross validation

# %%
gs_linear.plot_best_model_by_hyperparam(
    partition_show="test",
    metric_show="r_squared_linreg",
    partition_select="val",
    metric_select="r_squared_linreg",
    param_x="um_radius",
    param_hue="model",
    graph_model_class='linear',
    baseline_model_class='linear_baseline',
    rename_levels = [
        ("model", {
            "LINEAR_MAX_NODES_PATIENT_1": "linear",
            "LINEAR_BASELINE_MAX_NODES_PATIENT_1": "baseline",
        })
    ],
    plot_mode = 'lineplot',
    palette = {"baseline": "C0", "linear": "C1"},
    xticks=[0, 10, 100, 1000, 6000],
)
# Out:
# subset was empty, available values for model are ['LINEAR_MAX_NODES_PATIENT_1'], given was ['LINEAR_BASELINE_MAX_NODES_PATIENT_1']
# subset was empty, available values for model are ['LINEAR_MAX_NODES_PATIENT_1'], given was ['LINEAR_BASELINE_MAX_NODES_PATIENT_1']
# subset was empty, available values for model are ['LINEAR_MAX_NODES_PATIENT_1'], given was ['LINEAR_BASELINE_MAX_NODES_PATIENT_1']
# subset was empty, available values for model are ['LINEAR_MAX_NODES_PATIENT_1'], given was ['LINEAR_BASELINE_MAX_NODES_PATIENT_1']
# subset was empty, available values for model are ['LINEAR_MAX_NODES_PATIENT_1'], given was ['LINEAR_BASELINE_MAX_NODES_PATIENT_1']
# subset was empty, available values for model are ['LINEAR_MAX_NODES_PATIENT_1'], given was ['LINEAR_BASELINE_MAX_NODES_PATIENT_1']
# subset was empty, available values for model are ['LINEAR_MAX_NODES_PATIENT_1'], given was ['LINEAR_BASELINE_MAX_NODES_PATIENT_1']
# subset was empty, available values for model are ['LINEAR_MAX_NODES_PATIENT_1'], given was ['LINEAR_BASELINE_MAX_NODES_PATIENT_1']

# %% [markdown]
# ## Chip cytometry - colon

# %%
gs_linear = ncem.train.GridSearchContainer(
    dir_gs, 
    gs_ids=[
        "210520_LINEAR_BASELINE_MAX_NODES_PATIENT_1_BUSCH",
        "210520_LINEAR_MAX_NODES_PATIENT_1_BUSCH",
        "210521_LINEAR_MAX_NODES_PATIENT_1_BUSCH"
    ],
    lateral_resolution=0.5
)
gs_linear.load_gs()
# Out:
# 210520_LINEAR_BASELINE_MAX_NODES_PATIENT_1_BUSCH: loaded 1 runs with 3-fold cross validation
# 210520_LINEAR_MAX_NODES_PATIENT_1_BUSCH: loaded 8 runs with 3-fold cross validation
# File '210521_linear_max_nodes_patient_1_busch_adam_lr1_agrFalse_predecTrue_bsS_md7_tk4_n100_fsstandard_ldi1_ei1_di1_ede1_dde1_dr1_l2N_l16_COND_cde1_cbTrue_cdi1_cdr1_cnh1_cl21_cv1_evaluation.pickle' missing
# File '210521_linear_max_nodes_patient_1_busch_adam_lr1_agrFalse_predecTrue_bsS_md7_tk4_n100_fsstandard_ldi1_ei1_di1_ede1_dde1_dr1_l2N_l16_COND_cde1_cbTrue_cdi1_cdr1_cnh1_cl21_cv1_history.pickle' missing
# File '210521_linear_max_nodes_patient_1_busch_adam_lr1_agrFalse_predecTrue_bsS_md7_tk4_n100_fsstandard_ldi1_ei1_di1_ede1_dde1_dr1_l2N_l16_COND_cde1_cbTrue_cdi1_cdr1_cnh1_cl21_cv1_hyperparam.pickle' missing
# File '210521_linear_max_nodes_patient_1_busch_adam_lr1_agrFalse_predecTrue_bsS_md7_tk4_n100_fsstandard_ldi1_ei1_di1_ede1_dde1_dr1_l2N_l16_COND_cde1_cbTrue_cdi1_cdr1_cnh1_cl21_cv1_model_args.pickle' missing
# File '210521_linear_max_nodes_patient_1_busch_adam_lr1_agrFalse_predecTrue_bsS_md7_tk4_n100_fsstandard_ldi1_ei1_di1_ede1_dde1_dr1_l2N_l16_COND_cde1_cbTrue_cdi1_cdr1_cnh1_cl21_cv1_time.pickle' missing
# File '210521_linear_max_nodes_patient_1_busch_adam_lr1_agrFalse_predecTrue_bsS_md7_tk4_n100_fsstandard_ldi1_ei1_di1_ede1_dde1_dr1_l2N_l16_COND_cde1_cbTrue_cdi1_cdr1_cnh1_cl21_cv2_evaluation.pickle' missing
# File '210521_linear_max_nodes_patient_1_busch_adam_lr1_agrFalse_predecTrue_bsS_md7_tk4_n100_fsstandard_ldi1_ei1_di1_ede1_dde1_dr1_l2N_l16_COND_cde1_cbTrue_cdi1_cdr1_cnh1_cl21_cv2_history.pickle' missing
# File '210521_linear_max_nodes_patient_1_busch_adam_lr1_agrFalse_predecTrue_bsS_md7_tk4_n100_fsstandard_ldi1_ei1_di1_ede1_dde1_dr1_l2N_l16_COND_cde1_cbTrue_cdi1_cdr1_cnh1_cl21_cv2_hyperparam.pickle' missing
# File '210521_linear_max_nodes_patient_1_busch_adam_lr1_agrFalse_predecTrue_bsS_md7_tk4_n100_fsstandard_ldi1_ei1_di1_ede1_dde1_dr1_l2N_l16_COND_cde1_cbTrue_cdi1_cdr1_cnh1_cl21_cv2_model_args.pickle' missing
# File '210521_linear_max_nodes_patient_1_busch_adam_lr1_agrFalse_predecTrue_bsS_md7_tk4_n100_fsstandard_ldi1_ei1_di1_ede1_dde1_dr1_l2N_l16_COND_cde1_cbTrue_cdi1_cdr1_cnh1_cl21_cv2_time.pickle' missing
# Run '210521_linear_max_nodes_patient_1_busch_adam_lr1_agrFalse_predecTrue_bsS_md7_tk4_n100_fsstandard_ldi1_ei1_di1_ede1_dde1_dr1_l2N_l16_COND_cde1_cbTrue_cdi1_cdr1_cnh1_cl21' not successful_cv2
# 210521_LINEAR_MAX_NODES_PATIENT_1_BUSCH: loaded 70 runs with 3-fold cross validation

# %%
gs_linear.plot_best_model_by_hyperparam(
    partition_show="test",
    metric_show="r_squared_linreg",
    partition_select="val",
    metric_select="r_squared_linreg",
    param_x="um_radius",
    param_hue="model",
    graph_model_class='linear',
    baseline_model_class='linear_baseline',
    rename_levels = [
        ("model", {
            "LINEAR_MAX_NODES_PATIENT_1": "linear",
            "LINEAR_BASELINE_MAX_NODES_PATIENT_1": "baseline",
        })
    ],
    plot_mode = 'lineplot',
    palette = {"baseline": "C0", "linear": "C1"},
    xticks=[ 0,  10, 40, 100, 400, 2500],
)
# Out:
# subset was empty, available values for model are ['LINEAR_MAX_NODES_PATIENT_1'], given was ['LINEAR_BASELINE_MAX_NODES_PATIENT_1']
# subset was empty, available values for model are ['LINEAR_MAX_NODES_PATIENT_1'], given was ['LINEAR_BASELINE_MAX_NODES_PATIENT_1']
# subset was empty, available values for model are ['LINEAR_MAX_NODES_PATIENT_1'], given was ['LINEAR_BASELINE_MAX_NODES_PATIENT_1']
# subset was empty, available values for model are ['LINEAR_MAX_NODES_PATIENT_1'], given was ['LINEAR_BASELINE_MAX_NODES_PATIENT_1']
# subset was empty, available values for model are ['LINEAR_MAX_NODES_PATIENT_1'], given was ['LINEAR_BASELINE_MAX_NODES_PATIENT_1']
# subset was empty, available values for model are ['LINEAR_MAX_NODES_PATIENT_1'], given was ['LINEAR_BASELINE_MAX_NODES_PATIENT_1']
# subset was empty, available values for model are ['LINEAR_MAX_NODES_PATIENT_1'], given was ['LINEAR_BASELINE_MAX_NODES_PATIENT_1']
# /mnt/home/icb/anna.schaar/git/ncem/ncem/train/summaries.py:469: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   summary_table[l] = [d[x] for x in summary_table[l].values]
# /mnt/home/icb/anna.schaar/git/ncem/ncem/train/summaries.py:473: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   summary_table[ycol] = [np.min([ylim[1], np.max([ylim[0], x])]) for x in summary_table[ycol].values]

# %% [markdown]
# # MIBI TOF - cancer

# %%
gs_linear = ncem.train.GridSearchContainer(
    dir_gs, 
    gs_ids=[
        "210520_LINEAR_BASELINE_MAX_NODES_IMAGE_1_HARTMANN",
        "210520_LINEAR_MAX_NODES_IMAGE_1_HARTMANN",
    ],
    lateral_resolution = 400/1024
)
gs_linear.load_gs()
# Out:
# 210520_LINEAR_BASELINE_MAX_NODES_IMAGE_1_HARTMANN: loaded 1 runs with 3-fold cross validation
# 210520_LINEAR_MAX_NODES_IMAGE_1_HARTMANN: loaded 6 runs with 3-fold cross validation

# %%
gs_linear.plot_best_model_by_hyperparam(
    partition_show="test",
    metric_show="r_squared_linreg",
    partition_select="val",
    metric_select="r_squared_linreg",
    param_x="um_radius",
    param_hue="model",
    graph_model_class='linear',
    baseline_model_class='linear_baseline',
    rename_levels = [
        ("model", {
            "LINEAR_BASELINE_MAX_NODES_IMAGE_1": "baseline",
            "LINEAR_MAX_NODES_IMAGE_1": "linear",
        })
    ],
    palette = {"baseline": "C0", "linear": "C1"},
    xticks=[0, 19, 46, 156, 625],
    plot_mode = 'lineplot',
)
# Out:
# subset was empty, available values for model are ['LINEAR_MAX_NODES_IMAGE_1'], given was ['LINEAR_BASELINE_MAX_NODES_IMAGE_1']
# subset was empty, available values for model are ['LINEAR_MAX_NODES_IMAGE_1'], given was ['LINEAR_BASELINE_MAX_NODES_IMAGE_1']
# subset was empty, available values for model are ['LINEAR_MAX_NODES_IMAGE_1'], given was ['LINEAR_BASELINE_MAX_NODES_IMAGE_1']
# subset was empty, available values for model are ['LINEAR_MAX_NODES_IMAGE_1'], given was ['LINEAR_BASELINE_MAX_NODES_IMAGE_1']
# subset was empty, available values for model are ['LINEAR_MAX_NODES_IMAGE_1'], given was ['LINEAR_BASELINE_MAX_NODES_IMAGE_1']

# %% [markdown]
# # MELC - tonsils data

# %%
gs_linear = ncem.train.GridSearchContainer(
    dir_gs, 
    gs_ids=[
        "210520_LINEAR_BASELINE_MAX_NODES_PATIENT_1_pascualreguanttonsil",
        "210520_LINEAR_MAX_NODES_PATIENT_1_pascualreguanttonsil",
    ],
    lateral_resolution = 0.325
)
gs_linear.load_gs()
# Out:
# 210520_LINEAR_BASELINE_MAX_NODES_PATIENT_1_pascualreguanttonsil: loaded 1 runs with 3-fold cross validation
# 210520_LINEAR_MAX_NODES_PATIENT_1_pascualreguanttonsil: loaded 8 runs with 3-fold cross validation

# %%
gs_linear.plot_best_model_by_hyperparam(
    partition_show="test",
    metric_show="r_squared_linreg",
    partition_select="val",
    metric_select="r_squared_linreg",
    param_x="um_radius",
    param_hue="model",
    graph_model_class='linear',
    baseline_model_class='linear_baseline',
    rename_levels = [
        ("model", {
            "LINEAR_BASELINE_MAX_NODES_PATIENT_1": "baseline",
            "LINEAR_MAX_NODES_PATIENT_1": "linear",
        })
    ],
    plot_mode = 'lineplot',
    palette = {"baseline": "C0", "linear": "C1"},
    xticks=[0,4,19,81,162, 975],
)
# Out:
# subset was empty, available values for model are ['LINEAR_MAX_NODES_PATIENT_1'], given was ['LINEAR_BASELINE_MAX_NODES_PATIENT_1']
# subset was empty, available values for model are ['LINEAR_MAX_NODES_PATIENT_1'], given was ['LINEAR_BASELINE_MAX_NODES_PATIENT_1']
# subset was empty, available values for model are ['LINEAR_MAX_NODES_PATIENT_1'], given was ['LINEAR_BASELINE_MAX_NODES_PATIENT_1']
# subset was empty, available values for model are ['LINEAR_MAX_NODES_PATIENT_1'], given was ['LINEAR_BASELINE_MAX_NODES_PATIENT_1']
# subset was empty, available values for model are ['LINEAR_MAX_NODES_PATIENT_1'], given was ['LINEAR_BASELINE_MAX_NODES_PATIENT_1']
# subset was empty, available values for model are ['LINEAR_MAX_NODES_PATIENT_1'], given was ['LINEAR_BASELINE_MAX_NODES_PATIENT_1']
# subset was empty, available values for model are ['LINEAR_MAX_NODES_PATIENT_1'], given was ['LINEAR_BASELINE_MAX_NODES_PATIENT_1']

# %% [markdown]
# # CODEX - cancer

# %%
gs_linear = ncem.train.GridSearchContainer(
    dir_gs, 
    gs_ids=[
        "210520_LINEAR_BASELINE_MAX_NODES_IMAGE_1_SCHUERCH",
        "210520_LINEAR_MAX_NODES_IMAGE_1_SCHUERCH",
    ],
    lateral_resolution = 0.377442
)
gs_linear.load_gs()
# Out:
# 210520_LINEAR_BASELINE_MAX_NODES_IMAGE_1_SCHUERCH: loaded 1 runs with 3-fold cross validation
# 210520_LINEAR_MAX_NODES_IMAGE_1_SCHUERCH: loaded 6 runs with 3-fold cross validation

# %%
gs_linear.plot_best_model_by_hyperparam(
    partition_show="test",
    metric_show="r_squared_linreg",
    partition_select="val",
    metric_select="r_squared_linreg",
    param_x="um_radius",
    param_hue="model",
    graph_model_class='linear',
    baseline_model_class='linear_baseline',
    rename_levels = [
        ("model", {
            "LINEAR_BASELINE_MAX_NODES_IMAGE_1": "baseline",
            "LINEAR_MAX_NODES_IMAGE_1": "linear",
        })
    ],
    plot_mode = 'lineplot',
    palette = {"baseline": "C0", "linear": "C1"},
    xticks=[0,9,18,45,188,754],
)
# Out:
# subset was empty, available values for model are ['LINEAR_MAX_NODES_IMAGE_1'], given was ['LINEAR_BASELINE_MAX_NODES_IMAGE_1']
# subset was empty, available values for model are ['LINEAR_MAX_NODES_IMAGE_1'], given was ['LINEAR_BASELINE_MAX_NODES_IMAGE_1']
# subset was empty, available values for model are ['LINEAR_MAX_NODES_IMAGE_1'], given was ['LINEAR_BASELINE_MAX_NODES_IMAGE_1']
# subset was empty, available values for model are ['LINEAR_MAX_NODES_IMAGE_1'], given was ['LINEAR_BASELINE_MAX_NODES_IMAGE_1']
# subset was empty, available values for model are ['LINEAR_MAX_NODES_IMAGE_1'], given was ['LINEAR_BASELINE_MAX_NODES_IMAGE_1']
